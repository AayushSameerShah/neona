# %%
import neona
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(np.random.normal(0, 1, (10,3))).round(2)

# %%
neona.kdeplot(np.random.randint(0, 1000, 100))
# Out:
# <AxesSubplot:>

# %%
def scatterplot(x, y, spines=True, point_size=2,
                color="#59ffc5", point_marker='o', font_dict=dict(),
                show_values=None, ax=None, labels=None, legend=False, legend_label=None):

# %%
x = np.random.randint(0, 100, 100)
y = 2 * x + np.random.normal(5, 10, 100)

# %%
plt.figure(figsize=(30, 30))
neona.scatterplot(x, y, spines=False, point_marker='x', point_size=1, color='r', legend=True)
# Out:
# No handles with labels found to put in legend.
# <AxesSubplot:>
